# %%
import movielens_dataset

# %%
movies_df = movielens_dataset.items_df()
movies_df
# Out:
#       movie_id                         title  \
# 0            1                    Toy Story
# 1            2                      Jumanji
# 2            3             Grumpier Old Men
# 3            4            Waiting to Exhale
# 4            5  Father of the Bride Part II
# ...        ...                           ...
# 3878      3948             Meet the Parents
# 3879      3949          Requiem for a Dream
# 3880      3950                    Tigerland
# 3881      3951             Two Family House
# 3882      3952               Contender, The
#
#                                 genres  year original_title  imdb_id  \
# 0      [Animation, Children's, Comedy]  1995            NaN   114709
# 1     [Adventure, Children's, Fantasy]  1995            NaN   113497
# 2                    [Comedy, Romance]  1995            NaN   113228
# 3                      [Comedy, Drama]  1995            NaN   114885
# 4                             [Comedy]  1995            NaN   113041
# ...

# %%
reviews_df = movielens_dataset.reviews_df()
reviews_df
# Out:
#          user_id  movie_id  rating           timestamp
# 0              1      1193       5 2000-12-31 22:12:40
# 1              1       661       3 2000-12-31 22:35:09
# 2              1       914       3 2000-12-31 22:32:48
# 3              1      3408       4 2000-12-31 22:04:35
# 4              1      2355       5 2001-01-06 23:38:11
# ...          ...       ...     ...                 ...
# 1000204     6040      1091       1 2000-04-26 02:35:41
# 1000205     6040      1094       5 2000-04-25 23:21:27
# 1000206     6040       562       5 2000-04-25 23:19:06
# 1000207     6040      1096       4 2000-04-26 02:20:48
# 1000208     6040      1097       4 2000-04-26 02:19:29
#
# [1000209 rows x 4 columns]

# %%
len(reviews_df) / (reviews_df['movie_id'].nunique() * reviews_df['user_id'].nunique())
# Out:
# 0.044683625622312845
