# %%
import movielens_dataset
import pandas as pd

# %% [markdown]
# Here, we download the CSVs from the movielens dataset and Artificial links available from the internet that link the Movielens dataset to the corresponding IMDB movie. We need that information to download movie descriptions and images. We can ignore all the information from the Movielens dataset and we parse all of it from IMDB. The movielens dataset has few data for our needs.

# %%
# For example, we can use smaller datasets, although in the paper we used ML-25M
movielens_dataset.download_movielens_dataset('ml-25m')
# Out:
# ...
#                                 title  \
# movie_id
# 1                           Toy Story
# 2                             Jumanji
# 3                    Grumpier Old Men
# 4                   Waiting to Exhale
# 5         Father of the Bride Part II
# ...                               ...
# 209157                             We
# 209159             Window of the Soul
# 209163                      Bad Poems
# 209169                   A Girl Thing
# 209171        Women of Devil's Island
#
#                                             genres_ml  year    imdb_id  \
# movie_id
# 1         Adventure|Animation|Children|Comedy|Fantasy  1995  tt0114709
# 2                          Adventure|Children|Fantasy  1995  tt0113497
# 3                                      Comedy|Romance  1995  tt0113228
# 4                                Comedy|Drama|Romance  1995  tt0114885
# 5                                              Comedy  1995  tt0113041
# ...

# %% [markdown]
# Since we are crawling a website, it is possible IMDB rate limit us, resulting in HTTP 403 error.
# We can attempt to restart the process by re-running this cell resuming the downloads.
#
# This process take around 5 hours, depending on the download speed.

# %%
from importlib import reload
reload(movielens_dataset)

movies_df = movielens_dataset.items_df('ml-25m')
movies_df
# Out:
# ...
#  17%|█▋        | 10123/58058 [57:45<4:33:28,  2.92movie/s]

# %%
movies_df['description'].isna().value_counts(normalize=True)

# %%
movies_df['image_slug'].apply(len).value_counts(normalize=True) * 100

# %%
reviews_df = movielens_dataset.reviews_df('ml-1m')
reviews_df

# %%
len(reviews_df) / (reviews_df['item_id'].nunique() * reviews_df['user_id'].nunique())
